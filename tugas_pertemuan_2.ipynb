# %% [markdown]
# Scrapping

# %%
# !pip install google-play-scraper

# %%
#import library
from google_play_scraper import Sort, reviews
from google_play_scraper import app

#import pandas yang digunakan untuk analisis dan manipulasi data
import pandas as pd

#import numpy yang digunakan untuk memproses array multidimensi
import numpy as np

# %%
#mulai scraping
result, continuation_token = reviews(
    'com.naver.linewebtoon',
    lang='id', #bahasa indonesia
    country='id', #negara indonesia
    sort=Sort.MOST_RELEVANT, #sorting yang paling relevan
    count=10000, #jumlah dataset
    filter_score_with=None
)

# %%
#membuat Dataframe dari hasil scraping
data = pd.DataFrame(np.array(result),columns=['review'])

data = data.join(pd.DataFrame(data.pop('review').tolist()))

data
# Out:
#                                   reviewId         userName  \
# 0     1a2b5170-9713-491f-8d81-dfd455c4cac9  Pengguna Google
# 1     f8f638d5-c6c0-4f0f-a0f0-1170b51e2455  Pengguna Google
# 2     4df142a8-7032-480e-964b-6f9000bc23da  Pengguna Google
# 3     4b9af441-7783-448f-bde9-933a43865d28  Pengguna Google
# 4     ec00b8e9-8a31-40c8-b276-dc0b4221887c  Pengguna Google
# ...                                    ...              ...
# 9995  9bcb80fa-f0fd-40ba-a15f-43972c5a8204  Femas Ade putra
# 9996  492e43d3-ebcc-44c7-8179-668b85d4f2e0    Bilqis Yasmin
# 9997  d551dda4-8471-461c-aa8d-8eca72d035ab  Pengguna Google
# 9998  1d417147-330b-4f0b-9d99-a5b41337b76e      My Treasure
# 9999  f9e23495-3998-4817-8867-c4dc8172c304  Pengguna Google
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
data.head()
# Out:
#                                reviewId         userName  \
# 0  1a2b5170-9713-491f-8d81-dfd455c4cac9  Pengguna Google
# 1  f8f638d5-c6c0-4f0f-a0f0-1170b51e2455  Pengguna Google
# 2  4df142a8-7032-480e-964b-6f9000bc23da  Pengguna Google
# 3  4b9af441-7783-448f-bde9-933a43865d28  Pengguna Google
# 4  ec00b8e9-8a31-40c8-b276-dc0b4221887c  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  bagus bgt, suka sama cerita2 nya, bisa dibaca ...      5             35
# 1  baguss bgtttt aplikasi nyaa, bykk jenis komik ...      4             17
# ...

# %%
data.tail()
# Out:
#                                   reviewId         userName  \
# 9995  9bcb80fa-f0fd-40ba-a15f-43972c5a8204  Femas Ade putra
# 9996  492e43d3-ebcc-44c7-8179-668b85d4f2e0    Bilqis Yasmin
# 9997  d551dda4-8471-461c-aa8d-8eca72d035ab  Pengguna Google
# 9998  1d417147-330b-4f0b-9d99-a5b41337b76e      My Treasure
# 9999  f9e23495-3998-4817-8867-c4dc8172c304  Pengguna Google
#
#                                               userImage  \
# 9995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9997  https://play-lh.googleusercontent.com/EGemoI2N...
# 9998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 9995  Kok nge lag nge lag sih pas loading baca , pad...      1              0
# 9996  sangat bagus! disini ceritanya sangat bagus, y...      5              0
# ...

# %%
len(data)
# Out:
# 10000

# %%
#mengambil fitur konten dan score
data = data[['content','score']]
data
# Out:
#                                                 content  score
# 0     bagus bgt, suka sama cerita2 nya, bisa dibaca ...      5
# 1     baguss bgtttt aplikasi nyaa, bykk jenis komik ...      4
# 2     Bintang 5!! tapi anehnya, kalau aku mau buka e...      4
# 3     Terpaksa saya rate bintang satu karena semakin...      1
# 4     sekarang makin susah baca pake fitur iklan, pa...      1
# ...                                                 ...    ...
# 9995  Kok nge lag nge lag sih pas loading baca , pad...      1
# 9996  sangat bagus! disini ceritanya sangat bagus, y...      5
# 9997  ini latarnya kan masih putih sederhana gitu na...      4
# 9998  kenapa fitur rising star nya dihapus? itu cmn ...      4
# 9999  udah lama pake apl ini, tapi skrg kecewa karna...      2
#
# [10000 rows x 2 columns]

# %%
#mengganti nama fitur
data = data.rename(columns={'content': 'ulasan', 'score': 'label'})
data
# Out:
#                                                  ulasan  label
# 0     bagus bgt, suka sama cerita2 nya, bisa dibaca ...      5
# 1     baguss bgtttt aplikasi nyaa, bykk jenis komik ...      4
# 2     Bintang 5!! tapi anehnya, kalau aku mau buka e...      4
# 3     Terpaksa saya rate bintang satu karena semakin...      1
# 4     sekarang makin susah baca pake fitur iklan, pa...      1
# ...                                                 ...    ...
# 9995  Kok nge lag nge lag sih pas loading baca , pad...      1
# 9996  sangat bagus! disini ceritanya sangat bagus, y...      5
# 9997  ini latarnya kan masih putih sederhana gitu na...      4
# 9998  kenapa fitur rising star nya dihapus? itu cmn ...      4
# 9999  udah lama pake apl ini, tapi skrg kecewa karna...      2
#
# [10000 rows x 2 columns]

# %%
#mengekspor dataset
data.to_csv("Ulasan Webtoon.csv", index=False, encoding='utf-8')

# %% [markdown]
# Case Folding

# %%
import pandas as pd

# %%
df = pd.read_csv("Ulasan Webtoon.csv")

# %%
kalimat = "Bintang 5!! tapi anehnya, kalau aku mau buka episode yang iklan/berbayar kadang lama gitu memperoleh iklannya... ga tau kenapa, padahal wifi ku udah lancar lancar aja, tapi tetap aja gabisa... jujur agak kesel sih... kalau ada komik favorite tapi pas mau lanjut ga bisa dan harus nunggu hari, atau bayar... sebenarnya aku ga tau apa yang salah... tapi mungkin bisa tolong di perbaiki bisa engga ya?? tapi overall ini bagus banget sumpah!! lopeee... sukses terus Webtoon!!!"
lower_case = kalimat.lower()
print(lower_case)
# Out:
# bintang 5!! tapi anehnya, kalau aku mau buka episode yang iklan/berbayar kadang lama gitu memperoleh iklannya... ga tau kenapa, padahal wifi ku udah lancar lancar aja, tapi tetap aja gabisa... jujur agak kesel sih... kalau ada komik favorite tapi pas mau lanjut ga bisa dan harus nunggu hari, atau bayar... sebenarnya aku ga tau apa yang salah... tapi mungkin bisa tolong di perbaiki bisa engga ya?? tapi overall ini bagus banget sumpah!! lopeee... sukses terus webtoon!!!

# %%
df['ulasan_casefold'] = df['ulasan'].astype(str).str.lower()

# %%
df.to_csv("Ulasan_Webtoon_Casefold.csv", index=False)
